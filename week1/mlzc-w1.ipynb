# %%
# !pip install pandas
# !pip install pyarrow
# !pip install scikit-learn scipy matplotlib

# %%
import pandas as pd

# %%
# Read parquet file
df = pd.read_parquet('./data/yellow_tripdata_2022-01.parquet')
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0  \
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID
# 0           3.80         1.0                  N           142           236  \
# 1           2.10         1.0                  N           236            42
# 2           0.97         1.0                  N           166           166
# 3           1.09         1.0                  N           114            68
# 4           4.30         1.0                  N            68           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount
# ...

# %%
# Create duration as a new feature
df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0  \
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID
# 0           3.80         1.0                  N           142           236  \
# 1           2.10         1.0                  N           236            42
# 2           0.97         1.0                  N           166           166
# 3           1.09         1.0                  N           114            68
# 4           4.30         1.0                  N            68           163
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount
# ...

# %%
# Standard deviation (4.64)
df['duration'].describe()
# Out:
# count    2.463931e+06
# mean     1.421220e+01
# std      4.644531e+01
# min     -3.442400e+03
# 25%      6.316667e+00
# 50%      1.018333e+01
# 75%      1.616667e+01
# max      8.513183e+03
# Name: duration, dtype: float64

# %%
# Percent after clean (98%)
df_clean = df[(df.duration >= 1) & (df.duration <= 60)]
percent = df_clean.shape[0]/df.shape[0]*100
percent
# Out:
# 98.27547930522405

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df_clean[categorical] = df_clean[categorical].astype(str)

df_clean.head()
# Out:
# /var/folders/bg/3702s1dj24x5wf6dpzjz4d1w0000gn/T/ipykernel_43229/2081155572.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean[categorical] = df_clean[categorical].astype(str)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0  \
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag PULocationID DOLocationID
# ...

# %%
train_dicts = df_clean[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df_clean[target].values

ohe = OneHotEncoder()
ohe.fit(X_train, y_train)

y_pred = ohe.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 10
#       7 y_train = df_clean[target].values
#       9 ohe = OneHotEncoder()
# ---> 10 ohe.fit(X_train, y_train)
#      12 y_pred = ohe.predict(X_train)
#      14 mean_squared_error(y_train, y_pred, squared=False)
#
# File ~/opt/anaconda3/envs/mlzc/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:878, in OneHotEncoder.fit(self, X, y)
#     874     self.sparse_output = self.sparse
#     876 self._check_infrequent_enabled()
# --> 878 fit_results = self._fit(
#     879     X,
#     880     handle_unknown=self.handle_unknown,
#     881     force_all_finite="allow-nan",
#     882     return_counts=self._infrequent_enabled,
#     883 )
#     884 if self._infrequent_enabled:
#     885     self._fit_infrequent_category_mapping(
#     886         fit_results["n_samples"], fit_results["category_counts"]
# ...
